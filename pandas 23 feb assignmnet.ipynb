# %%
#Q1. Create a Pandas Series that contains the following data: 4, 8, 15, 16, 23, and 42. Then, print the series.

# %%
import pandas as pd

# %%
data = pd.Series([4,18,15,16,23,42])

# %%
data
# Out:
# 0     4
# 1    18
# 2    15
# 3    16
# 4    23
# 5    42
# dtype: int64

# %%
#Q2. Create a variable of list type containing 10 elements in it, and apply pandas.Series function on the variable print it.

# %%
data1 = pd.Series([2,4,6,'hello','pandas',['this','is','a','list'],{'dict':"this ,is, a ,dict"},45.5,45+5j,99])

# %%
data1
# Out:
# 0                                2
# 1                                4
# 2                                6
# 3                            hello
# 4                           pandas
# 5              [this, is, a, list]
# 6    {'dict': 'this ,is, a ,dict'}
# 7                             45.5
# 8                          (45+5j)
# 9                               99
# dtype: object

# %%
#Q3. Create a Pandas DataFrame that contains the following data

# %% [markdown]
# ![df.png](attachment:96be15ca-d86d-4f24-a09f-7eacda5b3b2b.png)
# #Then, print the DataFrame.

# %%
details = {'name':['alice','bob','claire'],
            'age':[25,30,27],
            'gender':['female','male','female']}

# %%
pd.DataFrame(details , index = [1,2,3])
# Out:
#      name  age  gender
# 1   alice   25  female
# 2     bob   30    male
# 3  claire   27  female

# %%
#Q4. What is ‘DataFrame’ in pandas and how is it different from pandas.series? Explain with an example.

# %%
# Pandas Series	                        
# One-dimensional     	                
# Homogenous – Series elements must be of the same data type.
# Size-immutable – Once created, the size of a Series object cannot be changed.


# Pandas DataFrame
# Two-dimensional
# Heterogenous – DataFrame elements can have different data types.
# Size-mutable – Elements can be dropped or added in an existing DataFrame.

# %%
#panda series

ser = pd.Series([2,4,6,7,6,9,11])

# %%
ser
# Out:
# 0     2
# 1     4
# 2     6
# 3     7
# 4     6
# 5     9
# 6    11
# dtype: int64

# %%
#pandas dataframe

df = pd.DataFrame({'name':['deepankar','sudhanshu','karan'],
                 'age':[22,25,36],
                 'gender':['male','male','male']})

# %%
df
# Out:
#         name  age gender
# 0  deepankar   22   male
# 1  sudhanshu   25   male
# 2      karan   36   male

# %%
# Q5. What are some common functions you can use to manipulate data in a Pandas DataFrame? Can
# you give an example of when you might use one of these functions?

# %%
# 1.df.head(n) and df.tail(n):
# These functions are used to display the first or last n rows of a DataFrame, respectively. This can be useful for quickly checking the structure and contents of a DataFrame.

# 2. df.describe():
# This function generates descriptive statistics of the DataFrame, including count, mean, standard deviation, minimum, maximum, and quartiles. This can be helpful for gaining a quick understanding of the data.

# 3. df.info():
# This function displays information about the DataFrame, including the data types, non-null counts, and memory usage. This can be useful for checking the integrity of the data and identifying potential data quality issues.

# 4. df.dropna():
# This function drops any rows with missing values (NaN) from the DataFrame. This can be helpful for cleaning up the data before analysis.

# 5. df.groupby():
# This function groups the DataFrame by one or more columns and returns a new DataFrame with the groups. This can be useful for performing group-wise analysis or aggregations.

# 6. df.apply():
# This function applies a function to each element in a DataFrame or to a column or row of the DataFrame. This can be useful for performing custom transformations or calculations on the data.

# %%
#lets get a csv data first

csv = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

# %%
data1 =pd.read_csv(csv)

# %%
#head
data1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#tail
data1.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data1.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#info
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data1.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#groupby
#group by the survival of passengers
g = data1.groupby('Survived')

# %%
g.sum()
# Out:
# /tmp/ipykernel_4270/1197020669.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.sum()
#           PassengerId  Pclass       Age  SibSp  Parch        Fare      fareinr
# Survived
# 0              245412    1390  12985.50    304    181  12142.7199   971417.592
# 1              151974     667   8219.67    162    159  16551.2294  1324098.352

# %%
#apply
#convert the fare price in INR
data1['fareinr'] = data1['Fare'].apply(lambda x : x * 80)

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Q6.Which of the following is mutable in nature Series, DataFrame, Panel?

# %%
#All pandas data structures are value-mutable (the values they contain can be altered) but not always size-mutable. The length of a Series cannot be changed, but, for example, columns can be inserted into a DataFrame.

# %%
det = {'age':[22,23,24],
                    'name':['deepankar','karan','bhumit']}

# %%
df3 = pd.DataFrame(det)

# %%
df3
# Out:
#    age       name
# 0   22  deepankar
# 1   23      karan
# 2   24     bhumit

# %%
#changing the age
df3['age'] = [18,19,20]
df3
# Out:
#    age       name
# 0   18  deepankar
# 1   19      karan
# 2   20     bhumit

# %%
#Q7. Create a DataFrame using multiple Series. Explain with an example.

# %%
#making a series

games = pd.Series(['tekken','cod','gta'])
type = pd.Series(['fighting','war','open world'])

#putting series into a  dataframe
info = {'Games': games , 
       'Type': type }

df4 = pd.DataFrame(info)


df4
# Out:
#     Games        Type
# 0  tekken    fighting
# 1     cod         war
# 2     gta  open world
